# %% [markdown]
# В данном домашнем задании мы закрепляли навыки подготовки сырых данных NGS, а конкретнее использовали инструмент trimmomatic.
#
# Для начала мы скопировали сырые данные и адаптеры к ним себе в папку. Далее воспрользовались командой fastqc для того, чтобы получить информацию о качестве ридов.

# %% [markdown]
# ![Снимок экрана от 2025-05-07 10-40-24.png](data:image/png;base64,...)

# %% [markdown]
# Первый набор данных имеет удовлетворительное качество

# %% [markdown]
# ![Снимок экрана от 2025-05-07 10-40-31.png](data:image/png;base64,...)

# %% [markdown]
# Второй же, напротив, в неудовлетворительном состоянии.

# %% [markdown]
# Для подготовки данных проведём их тримминг. Сделаем это с помощью скрипта, который выложен на гитхаб. В этом скрипте мы пропишем удаление адаптеров, удалим основания с низким качеством в начале и конце и удалим короткие риды.

# %% [markdown]
# ![Снимок экрана от 2025-05-07 14-08-07.png](data:image/png;base64,...)

# %% [markdown]
# Как будто стало прям хорошо.

# %% [markdown]
# ![Снимок экрана от 2025-05-07 14-08-14.png](data:image/png;base64,...)

# %% [markdown]
# Немножко похуже

# %% [markdown]
# ![Снимок экрана от 2025-05-07 14-08-21.png](data:image/png;base64,...)

# %% [markdown]
# Лучше, чем было, но всё равно не предел мечтаний

# %% [markdown]
# ![Снимок экрана от 2025-05-07 14-08-27.png](data:image/png;base64,...)

# %% [markdown]
# А тут вообще ужас какой-то случился

# %% [markdown]
# Примем, что первый набор данных удалось привести в порядок, применим скрипт ещё раз для второго образца

# %% [markdown]
# ![Снимок экрана от 2025-05-07 14-47-15.png](data:image/png;base64,...)

# %% [markdown]
# Ну примерно как и было.

# %% [markdown]
# ![Снимок экрана от 2025-05-07 14-47-24.png](data:image/png;base64,...)

# %% [markdown]
# Выглядит странно, но как будто ему стало лучше. Хотя появившиеся крестики напрягают

# %% [markdown]
# ![Снимок экрана от 2025-05-07 14-47-35.png](data:image/png;base64,...)

# %% [markdown]
# Ну вроде чуть лучше стало, но всё равно как то страшно

# %% [markdown]
# ![Снимок экрана от 2025-05-07 14-47-42.png](data:image/png;base64,...)

# %% [markdown]
# С одной стороны теперь есть зелёная галочка, а с другой а куда всё делось? Видно настолько плохой образец, что вырезалось практически всё.
