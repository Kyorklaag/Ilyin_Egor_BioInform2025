# %% [markdown]
# # Домашнее задание №6

# %% [markdown]
# В данном домашнем задании нужно было найти белковые домены в геномах двух организмов. Я выбрал европейского ежа (Erinaceus europaeus) и дельфина афалину (Tursiops truncatus), потому что они милые. В качестве таргетного домена использовалась цистиновая петля, структурный мотив, имеющий три дисульфидных мостика, взаимное расположение которых образует петлю из аминокислотной последовательности. Этот мотив часто встречается у пептидных гормонов и факторов роста.

# %% [markdown]
# После применения hmmer было получено два текстовых файла, которые можно найти на GitHub как "hedgehog.tbl" и "dolphin.tbl". В них было выбрано два белка, которые у обоих видов имеют наименьший e-value. Ими оказались тиреотропный и фолликулостимулирующие гормоны.

# %% [markdown]
# Далее было проведено множественное выравнивание этих четырёх последовательностей, которое приведено ниже:

# %%
from IPython.display import Image
Image('выравнивание.png')

# %% [markdown]
# Можно увидеть, что все последовательности имеют цистеиновые остатки, которые находятся на соответствующих позициях, которые отмечены красными точками. Это является характерной для данного мотива чертой.
