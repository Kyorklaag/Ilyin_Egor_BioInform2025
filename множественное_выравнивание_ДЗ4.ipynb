# %% [markdown]
# # Домашнее задание №4

# %% [markdown]
# В данном задании нужно было выбрать четыре гомологичных белка у разных организмов. Выбор белка оказался не такой простой задачей, как казалось ранее. Изначально я выбрал альфа субъединицу тубулина, однако данный белок оказался крайне консервативным, поэтому я продолжил подбор. Далее я рассмотрел миоглобин, но его последовательность показалась мне слишком маленькой. Потом я попробвал кинезин, но данные по нему есть у очень ограниченного количества организмов. В итоге мой выбор пал на коллаген первого типа, белок внеклеточного матрикса, содержащийся в соединительных тканях и придающий им эластические свойства. Относится к фибрилярным белкам и образует тройные спирали.

# %% [markdown]
# Я выбрал следующие организмы: человек (Homo sapiens), корова (Bos taurus), собака (Canis lupus) и курица (Gallus gallus).

# %% [markdown]
# Далее я воспользовался инструментом MAFFT и получил newick файл. С помощью сайта, указанного в задании, было построено филогенетическое дерево:

# %%
from IPython.display import Image
Image('древо.png')

# %% [markdown]
# Данное дерево иллюстрирует довольно забавную систему родственных отношений, согласно которой курица и собака относятся к одной монофилетической группе, которая при этом не включает корову и человека.
